# %% [markdown]
# # {{number}}. {{title}}
#
# [Problem]({{url}}) · difficulty: {{difficulty}}

# %% [markdown]
# ## Intuition
#
# _Why the naive approach is too slow, and what structure the fast one exploits._

# %%
import pathlib, sys

# works from the problem directory or the project root
ROOT = next(p for p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents] if (p / 'lc').is_dir())
PROBLEM = ROOT / 'problems' / '{{number}}-{{slug}}'
sys.path.insert(0, str(ROOT))

from lc.harness import as_cases, load_solutions, run

solutions = load_solutions(PROBLEM)
solutions

# %% [markdown]
# ## Walking through an example

# %%
case = as_cases([((), None)])[0]  # replace with a real case
# run(solutions[-1], case)

# %% [markdown]
# ## Complexity
#
# | Approach | Time | Space |
# |---|---|---|
# | | | |
